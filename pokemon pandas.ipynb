# %%
import pandas as pd
## to read the csv
df=pd.read_csv('C:/Users/livia babu/OneDrive/Desktop/Data sets and certificate/pokemon/pokemon_data.csv')

# %% [markdown]
# ### reading the data

# %%
## head
print(df.head(3))

## read header 
##df.columns

## read each columns
##print(df[['Name', 'HP']])


## read each rows using iloc
## print(df.iloc[1:3])

## read specific location (r,c)

##print(df.iloc[1,2])

## read each rows using loc
## print(df.loc[df['Type 1'] == 'Fire'])
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False

# %% [markdown]
# ### describe/ sorting

# %%
#df.describe()
#df.sort_values('Name', ascending = False)
#df.sort_values([ 'Type 1', 'HP'])
# Out:
#        #       Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 316  292   Shedinja    Bug   Ghost    1      90       45       30       30
# 230  213    Shuckle    Bug    Rock   20      10      230       10      230
# 462  415     Combee    Bug  Flying   30      30       42       30       42
# 603  543   Venipede    Bug  Poison   30      45       59       30       39
# 314  290    Nincada    Bug  Ground   31      45       90       30       30
# ..   ...        ...    ...     ...  ...     ...      ...      ...      ...
# 142  131     Lapras  Water     Ice  130      85       80       85       95
# 145  134   Vaporeon  Water     NaN  130      65       60      110       95
# 350  320    Wailmer  Water     NaN  130      70       35       70       35
# 655  594  Alomomola  Water     NaN  165      75       80       40       45
# 351  321    Wailord  Water     NaN  170      90       45       90       45
#
#      Speed  Generation  Legendary
# ...

# %% [markdown]
# ### making changes in data and adding a column

# %%
df['Total']= df.iloc[:,4:10].sum(axis=1)
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %% [markdown]
# ### filtering the data

# %%
df.loc[(df['Type 1'] =='Grass')& (df['Type 2'] == 'Poison')&(df['HP']> 70) ]
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 50    45              Vileplume  Grass  Poison   75      80       85      110
# 77    71             Victreebel  Grass  Poison   80     105       65      100
# 652  591              Amoonguss  Grass  Poison  114      85       70       85
#
#      Sp. Def  Speed  Generation  Legendary  Total
# 2        100     80           1      False    525
# 3        120     80           1      False    625
# 50        90     50           1      False    490
# 77        70     70           1      False    490
# 652       80     30           5      False    464

# %% [markdown]
# ### conditional filtering

# %%
df.loc[df['Total'] > 500, ['Generation','Legendary']] = ['Test 1', 'Test 2']

# %% [markdown]
# ### Aggregate Statistics (groupby)

# %%
df.groupby(['Type 1']).mean().sort_values('Defense', ascending= False)
# Out:
# C:\Users\livia babu\AppData\Local\Temp\ipykernel_15792\1759914268.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['Type 1']).mean().sort_values('Defense', ascending= False)
#                    #         HP      Attack     Defense    Sp. Atk    Sp. Def  \
# Type 1
# Steel     442.851852  65.222222   92.703704  126.370370  67.518519  80.629630
# Rock      392.727273  65.363636   92.863636  100.795455  63.340909  75.477273
# Dragon    474.375000  83.312500  112.125000   86.375000  96.843750  88.843750
# Ground    356.281250  73.781250   95.750000   84.843750  56.468750  62.750000
# Ghost     486.500000  64.437500   73.781250   81.187500  79.343750  76.468750
# Water     303.089286  72.062500   74.151786   72.946429  74.812500  70.517857
# ...

# %%
df.groupby(['Type 1']).mean().sort_values('Attack', ascending= False)
# Out:
# C:\Users\livia babu\AppData\Local\Temp\ipykernel_15792\1475722656.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['Type 1']).mean().sort_values('Attack', ascending= False)
#                    #         HP      Attack     Defense    Sp. Atk    Sp. Def  \
# Type 1
# Dragon    474.375000  83.312500  112.125000   86.375000  96.843750  88.843750
# Fighting  363.851852  69.851852   96.777778   65.925926  53.111111  64.703704
# Ground    356.281250  73.781250   95.750000   84.843750  56.468750  62.750000
# Rock      392.727273  65.363636   92.863636  100.795455  63.340909  75.477273
# Steel     442.851852  65.222222   92.703704  126.370370  67.518519  80.629630
# Dark      461.354839  66.806452   88.387097   70.225806  74.645161  69.516129
# ...

# %%
df.groupby(['Type 1']).count().sort_values('#', ascending = False)
# Out:
#             #  Name  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1
# Water     112   112      53  112     112      112      112      112    112
# Normal     98    98      37   98      98       98       98       98     98
# Grass      70    70      37   70      70       70       70       70     70
# Bug        69    69      52   69      69       69       69       69     69
# Psychic    57    57      19   57      57       57       57       57     57
# Fire       52    52      24   52      52       52       52       52     52
# Electric   44    44      17   44      44       44       44       44     44
# Rock       44    44      35   44      44       44       44       44     44
# Ghost      32    32      22   32      32       32       32       32     32
# Ground     32    32      19   32      32       32       32       32     32
# Dragon     32    32      21   32      32       32       32       32     32
# ...

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
## df['Legendary'].value_counts()
# Out:
# False    735
# True      65
# Name: Legendary, dtype: int64

# %%
##df['Type 1'].value_counts()
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %%
##df.loc[0:5,'HP':'Speed']
# Out:
#    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 0  45      49       49       65       65     45
# 1  60      62       63       80       80     60
# 2  80      82       83      100      100     80
# 3  80     100      123      122      120     80
# 4  39      52       43       60       50     65
# 5  58      64       58       80       65     80

# %%
## to set a new index
##df.set_index("#", inplace= True)

## to reset the index 
##df.reset_index(inplace=True)

## to sort the index asc / dec
## df.sort_index(ascending=False)
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
to rename the columns
## df.columns =[" "," ",]
#df=df.rename(columns={"#":"poke_index"})

# %%
df
# Out:
#      poke_index                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0             1              Bulbasaur    Grass  Poison  45      49       49
# 1             2                Ivysaur    Grass  Poison  60      62       63
# 2             3               Venusaur    Grass  Poison  80      82       83
# 3             3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4             4             Charmander     Fire     NaN  39      52       43
# ..          ...                    ...      ...     ...  ..     ...      ...
# 795         719                Diancie     Rock   Fairy  50     100      150
# 796         719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797         720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798         720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799         721              Volcanion     Fire   Water  80     110      120
#
# ...

# %%
##to save ur data 
## df.to_csv(''C:/Users/livia babu/OneDrive/Desktop/')

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
df
# Out:
#      poke_index                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0             1              Bulbasaur    Grass  Poison  45      49       49
# 1             2                Ivysaur    Grass  Poison  60      62       63
# 2             3               Venusaur    Grass  Poison  80      82       83
# 3             3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4             4             Charmander     Fire     NaN  39      52       43
# ..          ...                    ...      ...     ...  ..     ...      ...
# 795         719                Diancie     Rock   Fairy  50     100      150
# 796         719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797         720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798         720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799         721              Volcanion     Fire   Water  80     110      120
#
# ...

# %%
sns.set(style ='whitegrid')
plt.figure(figsize=(13,5))
sns.countplot(x='Type 1',data = df)
plt.title('Type 1 count')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
df2 = pd.read_csv('C:/Users/livia babu/Downloads/car dataset.csv')

# Count the number of sales by production year
sales_counts = df2['Prod. year'].value_counts()

# Get the top 5 production years with the highest sales
top_5_years = sales_counts.nlargest(5)

# Create a pie chart
plt.figure(figsize=(10, 6))
plt.pie(top_5_years.values, labels=top_5_years.index, autopct='%1.1f%%')
plt.title('Top 5 Production Years with the Highest Sales')

# Save the chart


# Get the top 5 years
top_5_years.index
# Out:
# Int64Index([2012, 2014, 2013, 2011, 2015], dtype='int64')

# %%
import matplotlib.pyplot as plt

# Calculate the count of cars by color
color_counts = df2['Color'].value_counts()

# Create a bar chart
plt.figure(figsize=(10, 6))
plt.bar(color_counts.index, color_counts.values, color='skyblue')
plt.xlabel('Color')
plt.ylabel('Count')
plt.title('Count of Cars by Color')
plt.xticks(rotation=90)


# Find the color with the most cars
max_color = color_counts.idxmax()
max_color
# Out:
# 'Black'
